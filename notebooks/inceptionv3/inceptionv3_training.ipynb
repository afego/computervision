# %%
cd E:/GitHub/computervision
# Out:
# E:\GitHub\computervision

# %%
import torch
import os
# os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

from torch.nn import BCELoss, CrossEntropyLoss
from datetime import datetime
from torch.optim import lr_scheduler, SGD, Adamax
from modules.training_util import PytorchDataset, PytorchTraining, EarlyStopping
from modules.models_util import InceptionV3

# %%
# Variables for continuing previous training
CONTINUE_TRAINING_DIR = None
# CONTINUE_TRAINING_DIR = 'notebooks/vit/models/'

MODEL_WEIGHTS_PATH = None

if CONTINUE_TRAINING_DIR:
    MODEL_WEIGHTS_PATH = os.path.join(CONTINUE_TRAINING_DIR,'epoch_15.pth')

# CONFIG VARIABLES
FULLY_TRAIN = True
base_path = 'E:/Datasets/cor-splits'
DATA_DIR = [
    # os.path.join(base_path,'sgkf-8-1-1-size-540'),
    # os.path.join(base_path,'underperforming_cameras_96'),
    # os.path.join(base_path,'underperforming_cameras_15'),
    # os.path.join(base_path,'underperforming_cameras_30'),
    os.path.join(base_path,'underperforming_cameras_60_v2'),
    # os.path.join(base_path,'underperforming_cameras_61_15img'),
    # os.path.join(base_path,'underperforming_cameras_59_45imgs'),
    # os.path.join(base_path,'random_cameras_61_30imgs'),
    # os.path.join(base_path,'random_cameras_59_45imgs'),
    # os.path.join(base_path,'random_cameras_71_15img'),
    # os.path.join(base_path,'underperforming_cameras_60_v2_euro'),
    # os.path.join(base_path,'underperforming_cameras_60_v2_itsc'),
    # os.path.join(base_path,'sgkf-8-2-size-1010'),
    # 'E:/Datasets/itsc_flood_dataset'
    ]
START_EPOCH = 1 # Change it from 1 if you're continuing an existing run
N_EPOCHS = 50
BATCH_SIZE = 16
SAVE_INTERVAL = 10 # How many epochs between each backup
## Learning Rate Scheduler
LR = [1e-04,1e-05]  # When continuing a existing run, update it to the last epoch LR value
LR_EPOCH_SCHEDULE = 5  # Number of epochs before altering LR
LR_GAMMA = 0.1
## Early Stopping
PATIENCE = 10
MIN_DELTA = 0
MIN_EPOCH = 10 # Number of epochs before starting patience counter
##
BP = [0.5]

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
for dir in DATA_DIR:
    for lr in LR:
        for brightness in BP:
            model_arch = InceptionV3(device=device, bp=brightness)
            
            model = model_arch.load(MODEL_WEIGHTS_PATH, FULLY_TRAIN)
            model = model.to(device)
            
            criterion = CrossEntropyLoss()
            if FULLY_TRAIN:
                params = model.parameters()
            else:
                params = model.fc.parameters()
                
            optimizer = SGD(params, lr=lr)
            # optimizer = Adamax(params, lr=lr)
            
            step_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=LR_EPOCH_SCHEDULE, gamma=LR_GAMMA)
            es = EarlyStopping(patience=PATIENCE, delta=MIN_DELTA, min_epoch=MIN_EPOCH)
            dataset = PytorchDataset(dir, model_arch.data_transforms, BATCH_SIZE)
            
            working_folder = 'notebooks/inceptionv3'
            models_folder = 'models'
            
            curr_time = datetime.now()
            curr_time = curr_time.strftime("%Y-%m-%d %H-%M-%S")
            
            output_folder = os.path.join(working_folder, models_folder)
            output_folder = os.path.join(output_folder, curr_time)
            
            if not os.path.exists(output_folder):
                os.makedirs(output_folder)
            trainer = PytorchTraining(device, dataset, output_folder)
            model = trainer.train_pytorch_model(model, criterion, optimizer, step_lr_scheduler, es, START_EPOCH, N_EPOCHS, SAVE_INTERVAL, "InceptionV3")
# Out:
# All parameters for model Inception3 requires grad.
# Saving model to folder notebooks/inceptionv3\models\2024-11-18 16-07-26
#
# Model Inception3 InceptionV3
# Fully Trained = True
# Dataset E:/Datasets/cor-splits\underperforming_cameras_60_v2
# Learning Rate Epoch Schedule = 5
# Learning Rate Gamma = 0.1
# Optimizer = SGD
# Batch Size = 16
#
#
# Epoch 1/50
# ----------
#
# train Loss: 0.7031 Acc: 0.5161
# val Loss: 0.6856 Acc: 0.5461
# Epoch duration: 0 m 52s
# Learning Rate = 0.0001
#
#
#
# Epoch 2/50
# ----------
#
# train Loss: 0.6922 Acc: 0.5359
# val Loss: 0.6724 Acc: 0.6118
# Epoch duration: 0 m 54s
# Learning Rate = 0.0001
#
#
#
# Epoch 3/50
# ----------
#
# train Loss: 0.6881 Acc: 0.5486
# val Loss: 0.6645 Acc: 0.6363
# Epoch duration: 0 m 55s
# Learning Rate = 0.0001
#
#
#
# Epoch 4/50
# ----------
#
# train Loss: 0.6776 Acc: 0.5678
# val Loss: 0.6548 Acc: 0.6667
# Epoch duration: 0 m 54s
# Learning Rate = 0.0001
#
#
#
# Epoch 5/50
# ----------
#
# train Loss: 0.6736 Acc: 0.5750
# val Loss: 0.6476 Acc: 0.6902
# Epoch duration: 0 m 58s
# Learning Rate = 1e-05
#
#
#
# Epoch 6/50
# ----------
#
# train Loss: 0.6680 Acc: 0.5956
# val Loss: 0.6455 Acc: 0.6912
# Epoch duration: 0 m 56s
# Learning Rate = 1e-05
#
#
#
# Epoch 7/50
# ----------
#
# train Loss: 0.6711 Acc: 0.5903
# val Loss: 0.6443 Acc: 0.7020
# Epoch duration: 0 m 57s
# Learning Rate = 1e-05
#
#
#
# Epoch 8/50
# ----------
#
# train Loss: 0.6696 Acc: 0.5873
# val Loss: 0.6454 Acc: 0.6990
# Epoch duration: 0 m 50s
# Learning Rate = 1e-05
#
#
#
# Epoch 9/50
# ----------
#
# train Loss: 0.6657 Acc: 0.5978
# val Loss: 0.6431 Acc: 0.7029
# Epoch duration: 0 m 53s
# Learning Rate = 1e-05
#
#
#
# Epoch 10/50
# ----------
#
# train Loss: 0.6688 Acc: 0.5926
# val Loss: 0.6429 Acc: 0.7010
# Epoch duration: 0 m 59s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 11/50
# ----------
#
# train Loss: 0.6715 Acc: 0.5767
# val Loss: 0.6404 Acc: 0.7039
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000002e-06
# Lower loss found, resetting patience counter
#
#
# Epoch 12/50
# ----------
#
# train Loss: 0.6677 Acc: 0.5914
# val Loss: 0.6431 Acc: 0.6961
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.6404. Increasing patience counter to 1
#
#
# Epoch 13/50
# ----------
#
# train Loss: 0.6673 Acc: 0.5998
# val Loss: 0.6417 Acc: 0.6971
# Epoch duration: 0 m 55s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.6404. Increasing patience counter to 2
#
#
# Epoch 14/50
# ----------
#
# train Loss: 0.6666 Acc: 0.6003
# val Loss: 0.6439 Acc: 0.7000
# Epoch duration: 0 m 59s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.6404. Increasing patience counter to 3
#
#
# Epoch 15/50
# ----------
#
# train Loss: 0.6656 Acc: 0.5937
# val Loss: 0.6410 Acc: 0.7029
# Epoch duration: 0 m 54s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6404. Increasing patience counter to 4
#
#
# Epoch 16/50
# ----------
#
# train Loss: 0.6668 Acc: 0.5951
# val Loss: 0.6427 Acc: 0.6902
# Epoch duration: 0 m 55s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6404. Increasing patience counter to 5
#
#
# Epoch 17/50
# ----------
#
# train Loss: 0.6638 Acc: 0.5964
# val Loss: 0.6413 Acc: 0.6971
# Epoch duration: 0 m 52s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6404. Increasing patience counter to 6
#
#
# Epoch 18/50
# ----------
#
# train Loss: 0.6659 Acc: 0.5875
# val Loss: 0.6433 Acc: 0.7000
# Epoch duration: 0 m 53s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6404. Increasing patience counter to 7
#
#
# Epoch 19/50
# ----------
#
# train Loss: 0.6685 Acc: 0.5959
# val Loss: 0.6419 Acc: 0.7049
# Epoch duration: 0 m 56s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6404. Increasing patience counter to 8
#
#
# Epoch 20/50
# ----------
#
# train Loss: 0.6659 Acc: 0.5939
# Model saved at notebooks/inceptionv3\models\2024-11-18 16-07-26/epoch_20.pth
# val Loss: 0.6434 Acc: 0.6980
# Model saved at notebooks/inceptionv3\models\2024-11-18 16-07-26/epoch_20.pth
# Epoch duration: 0 m 59s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6404. Increasing patience counter to 9
#
#
# Epoch 21/50
# ----------
#
# train Loss: 0.6650 Acc: 0.5945
# val Loss: 0.6436 Acc: 0.6961
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000004e-08
# Early stopping after 10 epochs
#
# Training complete in 19m 26s
# Best val Acc: 0.704902
#
# Confusion Matrix
# [[318 192]
#  [118 392]]
#
# Accuracy by class
# [62.35294118 76.8627451 ]
# All parameters for model Inception3 requires grad.
# Saving model to folder notebooks/inceptionv3\models\2024-11-18 16-26-52
#
# Model Inception3 InceptionV3
# Fully Trained = True
# Dataset E:/Datasets/cor-splits\underperforming_cameras_60_v2
# Learning Rate Epoch Schedule = 5
# Learning Rate Gamma = 0.1
# Optimizer = SGD
# Batch Size = 16
#
#
# Epoch 1/50
# ----------
#
# train Loss: 0.7207 Acc: 0.5086
# val Loss: 0.7207 Acc: 0.4922
# Epoch duration: 0 m 59s
# Learning Rate = 1e-05
#
#
#
# Epoch 2/50
# ----------
#
# train Loss: 0.7178 Acc: 0.4944
# val Loss: 0.7141 Acc: 0.4902
# Epoch duration: 0 m 58s
# Learning Rate = 1e-05
#
#
#
# Epoch 3/50
# ----------
#
# train Loss: 0.7168 Acc: 0.4981
# val Loss: 0.7119 Acc: 0.4873
# Epoch duration: 1 m 1s
# Learning Rate = 1e-05
#
#
#
# Epoch 4/50
# ----------
#
# train Loss: 0.7100 Acc: 0.4994
# val Loss: 0.7029 Acc: 0.5059
# Epoch duration: 0 m 57s
# Learning Rate = 1e-05
#
#
#
# Epoch 5/50
# ----------
#
# train Loss: 0.7009 Acc: 0.5214
# val Loss: 0.7035 Acc: 0.4971
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 6/50
# ----------
#
# train Loss: 0.7053 Acc: 0.5139
# val Loss: 0.7010 Acc: 0.5000
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 7/50
# ----------
#
# train Loss: 0.7050 Acc: 0.5192
# val Loss: 0.7044 Acc: 0.4990
# Epoch duration: 1 m 1s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 8/50
# ----------
#
# train Loss: 0.7010 Acc: 0.5197
# val Loss: 0.7010 Acc: 0.5020
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 9/50
# ----------
#
# train Loss: 0.7032 Acc: 0.5178
# val Loss: 0.7038 Acc: 0.4961
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 10/50
# ----------
#
# train Loss: 0.6986 Acc: 0.5245
# val Loss: 0.7012 Acc: 0.4814
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000002e-07
#
#
#
# Epoch 11/50
# ----------
#
# train Loss: 0.7010 Acc: 0.5181
# val Loss: 0.7009 Acc: 0.4804
# Epoch duration: 0 m 59s
# Learning Rate = 1.0000000000000002e-07
# Lower loss found, resetting patience counter
#
#
# Epoch 12/50
# ----------
#
# train Loss: 0.7007 Acc: 0.5242
# val Loss: 0.7020 Acc: 0.4882
# Epoch duration: 0 m 56s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.7009. Increasing patience counter to 1
#
#
# Epoch 13/50
# ----------
#
# train Loss: 0.7029 Acc: 0.5139
# val Loss: 0.6999 Acc: 0.4873
# Epoch duration: 0 m 54s
# Learning Rate = 1.0000000000000002e-07
# Lower loss found, resetting patience counter
#
#
# Epoch 14/50
# ----------
#
# train Loss: 0.7024 Acc: 0.5156
# val Loss: 0.7039 Acc: 0.4735
# Epoch duration: 0 m 52s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6999. Increasing patience counter to 1
#
#
# Epoch 15/50
# ----------
#
# train Loss: 0.7010 Acc: 0.5233
# val Loss: 0.7033 Acc: 0.4902
# Epoch duration: 0 m 54s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6999. Increasing patience counter to 2
#
#
# Epoch 16/50
# ----------
#
# train Loss: 0.7048 Acc: 0.5114
# val Loss: 0.7039 Acc: 0.4922
# Epoch duration: 0 m 54s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6999. Increasing patience counter to 3
#
#
# Epoch 17/50
# ----------
#
# train Loss: 0.7022 Acc: 0.5303
# val Loss: 0.6998 Acc: 0.4980
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000004e-08
# Lower loss found, resetting patience counter
#
#
# Epoch 18/50
# ----------
#
# train Loss: 0.7042 Acc: 0.5061
# val Loss: 0.7033 Acc: 0.4931
# Epoch duration: 0 m 56s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6998. Increasing patience counter to 1
#
#
# Epoch 19/50
# ----------
#
# train Loss: 0.7031 Acc: 0.5122
# val Loss: 0.7010 Acc: 0.4941
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6998. Increasing patience counter to 2
#
#
# Epoch 20/50
# ----------
#
# train Loss: 0.7035 Acc: 0.5167
# Model saved at notebooks/inceptionv3\models\2024-11-18 16-26-52/epoch_20.pth
# val Loss: 0.6998 Acc: 0.4902
# Model saved at notebooks/inceptionv3\models\2024-11-18 16-26-52/epoch_20.pth
# Epoch duration: 1 m 2s
# Learning Rate = 1.0000000000000005e-09
# Lower loss found, resetting patience counter
#
#
# Epoch 21/50
# ----------
#
# train Loss: 0.7035 Acc: 0.5161
# val Loss: 0.7019 Acc: 0.4990
# Epoch duration: 0 m 60s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6998. Increasing patience counter to 1
#
#
# Epoch 22/50
# ----------
#
# train Loss: 0.7007 Acc: 0.5175
# val Loss: 0.7023 Acc: 0.5010
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6998. Increasing patience counter to 2
#
#
# Epoch 23/50
# ----------
#
# train Loss: 0.7035 Acc: 0.5094
# val Loss: 0.7010 Acc: 0.4990
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6998. Increasing patience counter to 3
#
#
# Epoch 24/50
# ----------
#
# train Loss: 0.7019 Acc: 0.5206
# val Loss: 0.7026 Acc: 0.4951
# Epoch duration: 0 m 56s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6998. Increasing patience counter to 4
#
#
# Epoch 25/50
# ----------
#
# train Loss: 0.7042 Acc: 0.5142
# val Loss: 0.7017 Acc: 0.5029
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000006e-10
# Loss didnt decrease from 0.6998. Increasing patience counter to 5
#
#
# Epoch 26/50
# ----------
#
# train Loss: 0.7012 Acc: 0.5242
# val Loss: 0.7010 Acc: 0.4863
# Epoch duration: 0 m 58s
# Learning Rate = 1.0000000000000006e-10
# Loss didnt decrease from 0.6998. Increasing patience counter to 6
#
#
# Epoch 27/50
# ----------
#
# train Loss: 0.7051 Acc: 0.5108
# val Loss: 0.7017 Acc: 0.4980
# Epoch duration: 0 m 57s
# Learning Rate = 1.0000000000000006e-10
# Loss didnt decrease from 0.6998. Increasing patience counter to 7
#
#
# Epoch 28/50
# ----------
#
# train Loss: 0.7056 Acc: 0.5056
# val Loss: 0.7026 Acc: 0.4873
# Epoch duration: 0 m 55s
# Learning Rate = 1.0000000000000006e-10
# Loss didnt decrease from 0.6998. Increasing patience counter to 8
#
#
# Epoch 29/50
# ----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 34
#      32     os.makedirs(output_folder)
#      33 trainer = PytorchTraining(device, dataset, output_folder)
# ---> 34 model = trainer.train_pytorch_model(model, criterion, optimizer, step_lr_scheduler, es, START_EPOCH, N_EPOCHS, SAVE_INTERVAL, "InceptionV3")
#
# File E:\GitHub\computervision\modules\training_util.py:171, in PytorchTraining.train_pytorch_model(self, model, criterion, optimizer, scheduler, early_stopper, start_epoch, num_epochs, epoch_save_interval, model_info)
#     168 running_corrects = 0
#     170 # Iterate over data.
# --> 171 for inputs, labels, paths in self.dataset.dataloaders[phase]:
#     172     inputs = inputs.to(self.device)
#     173     labels = labels.to(self.device)
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\site-packages\torch\utils\data\dataloader.py:1329, in _MultiProcessingDataLoaderIter._next_data(self)
#    1326     return self._process_data(data)
#    1328 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1329 idx, data = self._get_data()
#    1330 self._tasks_outstanding -= 1
#    1331 if self._dataset_kind == _DatasetKind.Iterable:
#    1332     # Check for _IterableDatasetStopIteration
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\site-packages\torch\utils\data\dataloader.py:1295, in _MultiProcessingDataLoaderIter._get_data(self)
#    1291     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1292     # need to call `.task_done()` because we don't use `.join()`.
#    1293 else:
#    1294     while True:
# -> 1295         success, data = self._try_get_data()
#    1296         if success:
#    1297             return data
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\site-packages\torch\utils\data\dataloader.py:1133, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1120 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1121     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1122     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1130     # Returns a 2-tuple:
#    1131     #   (bool: whether successfully get data, any: data if successful else None)
#    1132     try:
# -> 1133         data = self._data_queue.get(timeout=timeout)
#    1134         return (True, data)
#    1135     except Exception as e:
#    1136         # At timeout and error, we manually check whether any worker has
#    1137         # failed. Note that this is the only mechanism for Windows to detect
#    1138         # worker failures.
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\multiprocessing\queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\multiprocessing\connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\multiprocessing\connection.py:346, in PipeConnection._poll(self, timeout)
#     343 if (self._got_empty_message or
#     344             _winapi.PeekNamedPipe(self._handle)[0] != 0):
#     345     return True
# --> 346 return bool(wait([self], timeout))
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\multiprocessing\connection.py:1083, in wait(object_list, timeout)
#    1080                 ready_objects.add(o)
#    1081                 timeout = 0
# -> 1083     ready_handles = _exhaustive_wait(waithandle_to_obj.keys(), timeout)
#    1084 finally:
#    1085     # request that overlapped reads stop
#    1086     for ov in ov_list:
#
# File c:\Users\Adm\anaconda3\envs\computervision\Lib\multiprocessing\connection.py:1015, in _exhaustive_wait(handles, timeout)
#    1013 ready = []
#    1014 while L:
# -> 1015     res = _winapi.WaitForMultipleObjects(L, False, timeout)
#    1016     if res == WAIT_TIMEOUT:
#    1017         break
#
# KeyboardInterrupt:
