# %%
cd E:/GitHub/computervision
# Out:
# E:\GitHub\computervision

# %%
import torch
import os
# os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

from torch.nn import BCELoss, CrossEntropyLoss
from datetime import datetime
from torch.optim import lr_scheduler, SGD, Adamax
from modules.training_util import PytorchDataset, PytorchTraining, EarlyStopping
from modules.models_util import MobileNet

# %%
# Variables for continuing previous training
CONTINUE_TRAINING_DIR = None
# CONTINUE_TRAINING_DIR = 'notebooks/vit/models/'

MODEL_WEIGHTS_PATH = None

if CONTINUE_TRAINING_DIR:
    MODEL_WEIGHTS_PATH = os.path.join(CONTINUE_TRAINING_DIR,'epoch_15.pth')

# CONFIG VARIABLES
FULLY_TRAIN = True
base_path = 'E:/Datasets/cor-splits'
DATA_DIR = [
    # os.path.join(base_path,'sgkf-8-1-1-size-540'),
    # os.path.join(base_path,'underperforming_cameras_96'),
    # os.path.join(base_path,'underperforming_cameras_15'),
    # os.path.join(base_path,'underperforming_cameras_30'),
    os.path.join(base_path,'underperforming_cameras_60_v2'),
    # os.path.join(base_path,'underperforming_cameras_61_15img'),
    # os.path.join(base_path,'underperforming_cameras_59_45imgs'),
    # os.path.join(base_path,'random_cameras_61_30imgs'),
    # os.path.join(base_path,'random_cameras_59_45imgs'),
    # os.path.join(base_path,'random_cameras_71_15img'),
    # os.path.join(base_path,'underperforming_cameras_60_v2_euro'),
    # os.path.join(base_path,'underperforming_cameras_60_v2_itsc'),
    # os.path.join(base_path,'sgkf-8-2-size-1010'),
    # 'E:/Datasets/itsc_flood_dataset'
    ]
START_EPOCH = 1 # Change it from 1 if you're continuing an existing run
N_EPOCHS = 50
BATCH_SIZE = 16
SAVE_INTERVAL = 10 # How many epochs between each backup
## Learning Rate Scheduler
LR = [1e-03,1e-04,1e-05]  # When continuing a existing run, update it to the last epoch LR value
LR_EPOCH_SCHEDULE = 5  # Number of epochs before altering LR
LR_GAMMA = 0.1
## Early Stopping
PATIENCE = 10
MIN_DELTA = 0
MIN_EPOCH = 10 # Number of epochs before starting patience counter
##
BP = [0.5]

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device = {device}")
archs = ['v2']
# Out:
# Device = cuda:0

# %%
for arch in archs:
    for dir in DATA_DIR:
        for lr in LR:
            for brightness in BP:
                model_arch = MobileNet(architecture=arch,bp=brightness)
                
                model = model_arch.load(MODEL_WEIGHTS_PATH, FULLY_TRAIN)
                model = model.to(device)
                
                criterion = CrossEntropyLoss()

                if FULLY_TRAIN:
                    params = model.parameters()
                else:
                    params = model.classifier.parameters()
                    
                optimizer = SGD(params, lr=lr)
                # optimizer = Adamax(params, lr=lr)

                step_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=LR_EPOCH_SCHEDULE, gamma=LR_GAMMA)
                es = EarlyStopping(patience=PATIENCE, delta=MIN_DELTA, min_epoch=MIN_EPOCH)
                dataset = PytorchDataset(dir, model_arch.data_transforms, BATCH_SIZE)

                working_folder = 'notebooks/mobilenetv2'
                models_folder = 'models'

                curr_time = datetime.now()
                curr_time = curr_time.strftime("%Y-%m-%d %H-%M-%S")

                output_folder = os.path.join(working_folder, models_folder)
                output_folder = os.path.join(output_folder, curr_time)
                
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                trainer = PytorchTraining(device, dataset, output_folder)
                model = trainer.train_pytorch_model(model, criterion, optimizer, step_lr_scheduler, es, START_EPOCH, N_EPOCHS, SAVE_INTERVAL, arch)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to C:\Users\Adm/.cache\torch\hub\checkpoints\mobilenet_v2-7ebf99e0.pth
# 100.0%
# All parameters for model MobileNetV2 requires grad.
# Saving model to folder notebooks/mobilenetv2\models\2024-11-18 13-42-33
#
# Model MobileNetV2 v2
# Fully Trained = True
# Dataset E:/Datasets/cor-splits\underperforming_cameras_60_v2
# Learning Rate Epoch Schedule = 5
# Learning Rate Gamma = 0.1
# Optimizer = SGD
# Batch Size = 16
#
#
# Epoch 1/50
# ----------
#
# train Loss: 0.6865 Acc: 0.5528
# val Loss: 0.6401 Acc: 0.6853
# Epoch duration: 0 m 45s
# Learning Rate = 0.001
#
#
#
# Epoch 2/50
# ----------
#
# train Loss: 0.6609 Acc: 0.6231
# val Loss: 0.6091 Acc: 0.7373
# Epoch duration: 0 m 44s
# Learning Rate = 0.001
#
#
#
# Epoch 3/50
# ----------
#
# train Loss: 0.6399 Acc: 0.6556
# val Loss: 0.5798 Acc: 0.7578
# Epoch duration: 0 m 44s
# Learning Rate = 0.001
#
#
#
# Epoch 4/50
# ----------
#
# train Loss: 0.6228 Acc: 0.6679
# val Loss: 0.5596 Acc: 0.7637
# Epoch duration: 0 m 44s
# Learning Rate = 0.001
#
#
#
# Epoch 5/50
# ----------
#
# train Loss: 0.6046 Acc: 0.6965
# val Loss: 0.5392 Acc: 0.7804
# Epoch duration: 0 m 44s
# Learning Rate = 0.0001
#
#
#
# Epoch 6/50
# ----------
#
# train Loss: 0.5985 Acc: 0.6968
# val Loss: 0.5365 Acc: 0.7784
# Epoch duration: 0 m 44s
# Learning Rate = 0.0001
#
#
#
# Epoch 7/50
# ----------
#
# train Loss: 0.5908 Acc: 0.7046
# val Loss: 0.5371 Acc: 0.7775
# Epoch duration: 0 m 45s
# Learning Rate = 0.0001
#
#
#
# Epoch 8/50
# ----------
#
# train Loss: 0.5907 Acc: 0.7012
# val Loss: 0.5303 Acc: 0.7853
# Epoch duration: 0 m 44s
# Learning Rate = 0.0001
#
#
#
# Epoch 9/50
# ----------
#
# train Loss: 0.5894 Acc: 0.7051
# val Loss: 0.5327 Acc: 0.7745
# Epoch duration: 0 m 45s
# Learning Rate = 0.0001
#
#
#
# Epoch 10/50
# ----------
#
# train Loss: 0.5869 Acc: 0.7068
# val Loss: 0.5322 Acc: 0.7784
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 11/50
# ----------
#
# train Loss: 0.5841 Acc: 0.7146
# val Loss: 0.5291 Acc: 0.7814
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
# Lower loss found, resetting patience counter
#
#
# Epoch 12/50
# ----------
#
# train Loss: 0.5905 Acc: 0.7059
# val Loss: 0.5307 Acc: 0.7804
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
# Loss didnt decrease from 0.5291. Increasing patience counter to 1
#
#
# Epoch 13/50
# ----------
#
# train Loss: 0.5827 Acc: 0.7151
# val Loss: 0.5307 Acc: 0.7784
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
# Loss didnt decrease from 0.5291. Increasing patience counter to 2
#
#
# Epoch 14/50
# ----------
#
# train Loss: 0.5878 Acc: 0.7021
# val Loss: 0.5317 Acc: 0.7794
# Epoch duration: 0 m 45s
# Learning Rate = 1e-05
# Loss didnt decrease from 0.5291. Increasing patience counter to 3
#
#
# Epoch 15/50
# ----------
#
# train Loss: 0.5845 Acc: 0.7129
# val Loss: 0.5332 Acc: 0.7814
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.5291. Increasing patience counter to 4
#
#
# Epoch 16/50
# ----------
#
# train Loss: 0.5856 Acc: 0.7104
# val Loss: 0.5304 Acc: 0.7804
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.5291. Increasing patience counter to 5
#
#
# Epoch 17/50
# ----------
#
# train Loss: 0.5845 Acc: 0.7143
# val Loss: 0.5328 Acc: 0.7833
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.5291. Increasing patience counter to 6
#
#
# Epoch 18/50
# ----------
#
# train Loss: 0.5853 Acc: 0.7143
# val Loss: 0.5298 Acc: 0.7794
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.5291. Increasing patience counter to 7
#
#
# Epoch 19/50
# ----------
#
# train Loss: 0.5845 Acc: 0.7137
# val Loss: 0.5288 Acc: 0.7814
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Lower loss found, resetting patience counter
#
#
# Epoch 20/50
# ----------
#
# train Loss: 0.5859 Acc: 0.7096
# Model saved at notebooks/mobilenetv2\models\2024-11-18 13-42-33/epoch_20.pth
# val Loss: 0.5251 Acc: 0.7765
# Model saved at notebooks/mobilenetv2\models\2024-11-18 13-42-33/epoch_20.pth
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Lower loss found, resetting patience counter
#
#
# Epoch 21/50
# ----------
#
# train Loss: 0.5904 Acc: 0.7015
# val Loss: 0.5302 Acc: 0.7745
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.5251. Increasing patience counter to 1
#
#
# Epoch 22/50
# ----------
#
# train Loss: 0.5848 Acc: 0.7068
# val Loss: 0.5286 Acc: 0.7882
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.5251. Increasing patience counter to 2
#
#
# Epoch 23/50
# ----------
#
# train Loss: 0.5874 Acc: 0.7076
# val Loss: 0.5290 Acc: 0.7824
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.5251. Increasing patience counter to 3
#
#
# Epoch 24/50
# ----------
#
# train Loss: 0.5863 Acc: 0.7110
# val Loss: 0.5295 Acc: 0.7784
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.5251. Increasing patience counter to 4
#
#
# Epoch 25/50
# ----------
#
# train Loss: 0.5862 Acc: 0.7090
# val Loss: 0.5285 Acc: 0.7804
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.5251. Increasing patience counter to 5
#
#
# Epoch 26/50
# ----------
#
# train Loss: 0.5863 Acc: 0.7101
# val Loss: 0.5291 Acc: 0.7804
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.5251. Increasing patience counter to 6
#
#
# Epoch 27/50
# ----------
#
# train Loss: 0.5888 Acc: 0.7004
# val Loss: 0.5299 Acc: 0.7824
# Epoch duration: 0 m 46s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.5251. Increasing patience counter to 7
#
#
# Epoch 28/50
# ----------
#
# train Loss: 0.5845 Acc: 0.7137
# val Loss: 0.5289 Acc: 0.7824
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.5251. Increasing patience counter to 8
#
#
# Epoch 29/50
# ----------
#
# train Loss: 0.5861 Acc: 0.7115
# val Loss: 0.5333 Acc: 0.7784
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.5251. Increasing patience counter to 9
#
#
# Epoch 30/50
# ----------
#
# train Loss: 0.5884 Acc: 0.7112
# Model saved at notebooks/mobilenetv2\models\2024-11-18 13-42-33/epoch_30.pth
# val Loss: 0.5291 Acc: 0.7814
# Model saved at notebooks/mobilenetv2\models\2024-11-18 13-42-33/epoch_30.pth
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000005e-09
# Early stopping after 10 epochs
#
# Training complete in 22m 11s
# Best val Acc: 0.788235
#
# Confusion Matrix
# [[390 120]
#  [103 407]]
#
# Accuracy by class
# [76.47058824 79.80392157]
# All parameters for model MobileNetV2 requires grad.
# Saving model to folder notebooks/mobilenetv2\models\2024-11-18 14-04-44
#
# Model MobileNetV2 v2
# Fully Trained = True
# Dataset E:/Datasets/cor-splits\underperforming_cameras_60_v2
# Learning Rate Epoch Schedule = 5
# Learning Rate Gamma = 0.1
# Optimizer = SGD
# Batch Size = 16
#
#
# Epoch 1/50
# ----------
#
# train Loss: 0.6957 Acc: 0.5131
# val Loss: 0.6892 Acc: 0.5314
# Epoch duration: 0 m 45s
# Learning Rate = 0.0001
#
#
#
# Epoch 2/50
# ----------
#
# train Loss: 0.6946 Acc: 0.5192
# val Loss: 0.6822 Acc: 0.5588
# Epoch duration: 0 m 44s
# Learning Rate = 0.0001
#
#
#
# Epoch 3/50
# ----------
#
# train Loss: 0.6910 Acc: 0.5303
# val Loss: 0.6792 Acc: 0.5657
# Epoch duration: 0 m 45s
# Learning Rate = 0.0001
#
#
#
# Epoch 4/50
# ----------
#
# train Loss: 0.6894 Acc: 0.5283
# val Loss: 0.6758 Acc: 0.5833
# Epoch duration: 0 m 45s
# Learning Rate = 0.0001
#
#
#
# Epoch 5/50
# ----------
#
# train Loss: 0.6830 Acc: 0.5461
# val Loss: 0.6680 Acc: 0.6029
# Epoch duration: 0 m 45s
# Learning Rate = 1e-05
#
#
#
# Epoch 6/50
# ----------
#
# train Loss: 0.6826 Acc: 0.5511
# val Loss: 0.6687 Acc: 0.5853
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 7/50
# ----------
#
# train Loss: 0.6802 Acc: 0.5650
# val Loss: 0.6693 Acc: 0.5971
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 8/50
# ----------
#
# train Loss: 0.6789 Acc: 0.5631
# val Loss: 0.6661 Acc: 0.5951
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 9/50
# ----------
#
# train Loss: 0.6790 Acc: 0.5645
# val Loss: 0.6681 Acc: 0.5922
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 10/50
# ----------
#
# train Loss: 0.6829 Acc: 0.5642
# val Loss: 0.6656 Acc: 0.6108
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 11/50
# ----------
#
# train Loss: 0.6791 Acc: 0.5659
# val Loss: 0.6655 Acc: 0.6039
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Lower loss found, resetting patience counter
#
#
# Epoch 12/50
# ----------
#
# train Loss: 0.6804 Acc: 0.5581
# val Loss: 0.6640 Acc: 0.6118
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Lower loss found, resetting patience counter
#
#
# Epoch 13/50
# ----------
#
# train Loss: 0.6809 Acc: 0.5561
# val Loss: 0.6697 Acc: 0.5922
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.6640. Increasing patience counter to 1
#
#
# Epoch 14/50
# ----------
#
# train Loss: 0.6833 Acc: 0.5614
# val Loss: 0.6674 Acc: 0.5990
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
# Loss didnt decrease from 0.6640. Increasing patience counter to 2
#
#
# Epoch 15/50
# ----------
#
# train Loss: 0.6800 Acc: 0.5664
# val Loss: 0.6667 Acc: 0.6039
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6640. Increasing patience counter to 3
#
#
# Epoch 16/50
# ----------
#
# train Loss: 0.6806 Acc: 0.5550
# val Loss: 0.6660 Acc: 0.6088
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6640. Increasing patience counter to 4
#
#
# Epoch 17/50
# ----------
#
# train Loss: 0.6801 Acc: 0.5645
# val Loss: 0.6697 Acc: 0.5892
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6640. Increasing patience counter to 5
#
#
# Epoch 18/50
# ----------
#
# train Loss: 0.6812 Acc: 0.5570
# val Loss: 0.6674 Acc: 0.5961
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6640. Increasing patience counter to 6
#
#
# Epoch 19/50
# ----------
#
# train Loss: 0.6822 Acc: 0.5506
# val Loss: 0.6670 Acc: 0.5990
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6640. Increasing patience counter to 7
#
#
# Epoch 20/50
# ----------
#
# train Loss: 0.6827 Acc: 0.5492
# Model saved at notebooks/mobilenetv2\models\2024-11-18 14-04-44/epoch_20.pth
# val Loss: 0.6669 Acc: 0.6049
# Model saved at notebooks/mobilenetv2\models\2024-11-18 14-04-44/epoch_20.pth
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6640. Increasing patience counter to 8
#
#
# Epoch 21/50
# ----------
#
# train Loss: 0.6794 Acc: 0.5659
# val Loss: 0.6673 Acc: 0.5931
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6640. Increasing patience counter to 9
#
#
# Epoch 22/50
# ----------
#
# train Loss: 0.6785 Acc: 0.5614
# val Loss: 0.6669 Acc: 0.6078
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Early stopping after 10 epochs
#
# Training complete in 16m 18s
# Best val Acc: 0.611765
#
# Confusion Matrix
# [[257 253]
#  [147 363]]
#
# Accuracy by class
# [50.39215686 71.17647059]
# All parameters for model MobileNetV2 requires grad.
# Saving model to folder notebooks/mobilenetv2\models\2024-11-18 14-21-03
#
# Model MobileNetV2 v2
# Fully Trained = True
# Dataset E:/Datasets/cor-splits\underperforming_cameras_60_v2
# Learning Rate Epoch Schedule = 5
# Learning Rate Gamma = 0.1
# Optimizer = SGD
# Batch Size = 16
#
#
# Epoch 1/50
# ----------
#
# train Loss: 0.6972 Acc: 0.5064
# val Loss: 0.6974 Acc: 0.5363
# Epoch duration: 0 m 45s
# Learning Rate = 1e-05
#
#
#
# Epoch 2/50
# ----------
#
# train Loss: 0.6932 Acc: 0.5261
# val Loss: 0.6956 Acc: 0.5392
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 3/50
# ----------
#
# train Loss: 0.6949 Acc: 0.5267
# val Loss: 0.6952 Acc: 0.5265
# Epoch duration: 0 m 45s
# Learning Rate = 1e-05
#
#
#
# Epoch 4/50
# ----------
#
# train Loss: 0.6938 Acc: 0.5203
# val Loss: 0.6956 Acc: 0.5382
# Epoch duration: 0 m 44s
# Learning Rate = 1e-05
#
#
#
# Epoch 5/50
# ----------
#
# train Loss: 0.6940 Acc: 0.5208
# val Loss: 0.6942 Acc: 0.5412
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 6/50
# ----------
#
# train Loss: 0.6951 Acc: 0.5108
# val Loss: 0.6959 Acc: 0.5392
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 7/50
# ----------
#
# train Loss: 0.6913 Acc: 0.5345
# val Loss: 0.6942 Acc: 0.5490
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 8/50
# ----------
#
# train Loss: 0.6935 Acc: 0.5281
# val Loss: 0.6948 Acc: 0.5422
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 9/50
# ----------
#
# train Loss: 0.6922 Acc: 0.5375
# val Loss: 0.6970 Acc: 0.5324
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-06
#
#
#
# Epoch 10/50
# ----------
#
# train Loss: 0.6935 Acc: 0.5228
# val Loss: 0.6952 Acc: 0.5402
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
#
#
#
# Epoch 11/50
# ----------
#
# train Loss: 0.6944 Acc: 0.5214
# val Loss: 0.6972 Acc: 0.5333
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Lower loss found, resetting patience counter
#
#
# Epoch 12/50
# ----------
#
# train Loss: 0.6941 Acc: 0.5170
# val Loss: 0.6942 Acc: 0.5578
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000002e-07
# Lower loss found, resetting patience counter
#
#
# Epoch 13/50
# ----------
#
# train Loss: 0.6941 Acc: 0.5233
# val Loss: 0.6963 Acc: 0.5314
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6942. Increasing patience counter to 1
#
#
# Epoch 14/50
# ----------
#
# train Loss: 0.6937 Acc: 0.5225
# val Loss: 0.6949 Acc: 0.5353
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000002e-07
# Loss didnt decrease from 0.6942. Increasing patience counter to 2
#
#
# Epoch 15/50
# ----------
#
# train Loss: 0.6923 Acc: 0.5289
# val Loss: 0.6936 Acc: 0.5343
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Lower loss found, resetting patience counter
#
#
# Epoch 16/50
# ----------
#
# train Loss: 0.6921 Acc: 0.5256
# val Loss: 0.6943 Acc: 0.5382
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6936. Increasing patience counter to 1
#
#
# Epoch 17/50
# ----------
#
# train Loss: 0.6940 Acc: 0.5267
# val Loss: 0.6947 Acc: 0.5353
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6936. Increasing patience counter to 2
#
#
# Epoch 18/50
# ----------
#
# train Loss: 0.6926 Acc: 0.5267
# val Loss: 0.6938 Acc: 0.5549
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6936. Increasing patience counter to 3
#
#
# Epoch 19/50
# ----------
#
# train Loss: 0.6949 Acc: 0.5133
# val Loss: 0.6940 Acc: 0.5422
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000004e-08
# Loss didnt decrease from 0.6936. Increasing patience counter to 4
#
#
# Epoch 20/50
# ----------
#
# train Loss: 0.6925 Acc: 0.5250
# Model saved at notebooks/mobilenetv2\models\2024-11-18 14-21-03/epoch_20.pth
# val Loss: 0.6939 Acc: 0.5471
# Model saved at notebooks/mobilenetv2\models\2024-11-18 14-21-03/epoch_20.pth
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6936. Increasing patience counter to 5
#
#
# Epoch 21/50
# ----------
#
# train Loss: 0.6944 Acc: 0.5142
# val Loss: 0.6950 Acc: 0.5343
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6936. Increasing patience counter to 6
#
#
# Epoch 22/50
# ----------
#
# train Loss: 0.6936 Acc: 0.5133
# val Loss: 0.6960 Acc: 0.5294
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6936. Increasing patience counter to 7
#
#
# Epoch 23/50
# ----------
#
# train Loss: 0.6927 Acc: 0.5261
# val Loss: 0.6940 Acc: 0.5451
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6936. Increasing patience counter to 8
#
#
# Epoch 24/50
# ----------
#
# train Loss: 0.6935 Acc: 0.5186
# val Loss: 0.6952 Acc: 0.5529
# Epoch duration: 0 m 45s
# Learning Rate = 1.0000000000000005e-09
# Loss didnt decrease from 0.6936. Increasing patience counter to 9
#
#
# Epoch 25/50
# ----------
#
# train Loss: 0.6931 Acc: 0.5208
# val Loss: 0.6960 Acc: 0.5373
# Epoch duration: 0 m 44s
# Learning Rate = 1.0000000000000006e-10
# Early stopping after 10 epochs
#
# Training complete in 18m 31s
# Best val Acc: 0.557843
#
# Confusion Matrix
# [[143 367]
#  [105 405]]
#
# Accuracy by class
# [28.03921569 79.41176471]
